# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# Import The Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Load The Dataset

# %%
credit_data=pd.read_csv("/content/creditcard.csv")
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 172436  121099.0  2.116162 -0.020723 -1.561986  0.180724  0.349837 -0.807017
# 172437  121099.0  0.072966  1.004738 -0.452590 -0.530909  0.904533 -0.717924
# 172438  121099.0 -0.469486  1.470284 -0.901081 -1.132544  1.007226 -1.826067
# 172439  121100.0 -0.022203  0.984425 -0.869132 -1.223516  1.204728 -1.256646
# 172440  121100.0  1.998499       NaN       NaN       NaN       NaN       NaN
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 172436  0.198311 -0.333762  0.635628  ...  0.218910  0.831076 -0.091030
# 172437  1.226208 -0.198730 -0.261541  ... -0.300872 -0.735995  0.186777
# 172438  1.709788 -0.501626 -0.051211  ...  0.188097  0.901185 -0.235127
# 172439  1.541838 -0.273428 -0.455793  ...  0.256388  0.871551 -0.304075
# 172440       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 172436 -0.727828  0.351949 -0.052626 -0.011690 -0.065137    1.00    0.0
# 172437  0.588969 -0.354524  0.107859  0.214559  0.090296   49.99    0.0
# 172438  0.098768 -0.201937  0.094018  0.607497  0.394638    0.69    0.0
# 172439 -0.384298 -0.328903  0.096864  0.384689  0.251776    0.75    0.0
# 172440       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# Check The Null values

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        1
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# Check The Legit Transction &  Fraulent Transction
#
#
#
# 0 -->  Normal/Legit  Transction
#
#
#
# 1  -->  Fraudalent Transction

# %%
credit_data["Class"].value_counts()
# Out:
# 0.0    172080
# 1.0       360
# Name: Class, dtype: int64

# %%
legit=credit_data[credit_data.Class==0]
fraud=credit_data[credit_data.Class==1]

# %%
print(legit.shape)
# Out:
# (172080, 31)

# %%
print(fraud.shape)
# Out:
# (360, 31)

# %%
legit.Amount.describe()
# Out:
# count    172080.000000
# mean         87.417004
# std         245.883009
# min           0.000000
# 25%           5.490000
# 50%          21.980000
# 75%          76.830000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     360.000000
# mean      111.576722
# std       227.309252
# min         0.000000
# 25%         1.000000
# 50%        11.385000
# 75%       104.007500
# max      1809.680000
# Name: Amount, dtype: float64

# %% [markdown]
# Compare The Value Both Transction

# %%
credit_data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    61640.665260 -0.153353  0.028968  0.499904  0.103724 -0.163749
# 1.0    56649.477778 -6.026758  4.406926 -7.976571  4.889177 -4.367960
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.060765 -0.064557  0.029671  0.024458  ...  0.029557 -0.029094
# 1.0   -1.436827 -7.017053  0.745264 -2.863575  ...  0.405161  0.793171
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.081659 -0.021812  0.008736  0.090348  0.012010  0.001711  0.002362
# 1.0   -0.025930 -0.037556 -0.073778  0.080099  0.038996  0.182902  0.052482
#
#            Amount
# Class
# 0.0     87.417004
# 1.0    111.576722
#
# [2 rows x 30 columns]

# %% [markdown]
# Bulit a  sample  dataset  which  containing  similar  distribution  of   Legit  Transaction  &   Fraudulent  Transaction
#
#
#
# In 284315  Legit Transaction, We going  to  take  492  Transaction   from  Legit   Transaction

# %%
legit_sample=legit.sample(n=492)
legit_sample.head()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# 54814  46632.0 -1.018584 -0.092689  2.930103  1.332177  0.316509 -0.077635
# 90746  63150.0 -0.595084  1.214295  0.955243  0.642108 -0.133806 -0.421115
# 92865  64144.0 -1.817424  2.216421 -0.349283 -0.107746 -0.465441 -0.689390
# 14195  25229.0  1.443703 -0.377190 -0.508375 -1.042034  0.154033 -0.012187
# 27330  34505.0  1.050866 -0.169382  0.402935  0.628737  0.196794  1.307176
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 54814 -0.440264  0.182523 -0.137089  ...  0.239263  0.750589 -0.274148
# 90746  0.180797  0.440709 -0.806657  ... -0.087536 -0.367404  0.135577
# 92865 -0.304887  1.196769 -0.670991  ... -0.236691 -0.814319  0.012729
# 14195 -0.159160 -0.162228 -1.124211  ... -0.244575 -0.805131 -0.044818
# 27330 -0.409791  0.504630  0.553994  ... -0.122470 -0.045982  0.152011
#
#             V24       V25       V26       V27       V28  Amount  Class
# 54814  0.342656  0.253575 -0.105705 -0.060641 -0.126038    1.00    0.0
# 90746  0.037320 -0.749086  0.180606  0.025895  0.094750    9.99    0.0
# 92865 -0.486925  0.165586  0.134633  0.101200  0.004746    9.99    0.0
# 14195 -1.333466  0.484115 -0.418444  0.000356  0.002413   34.00    0.0
# 27330 -0.937302  0.116560  0.400046  0.045021 -0.003846    3.71    0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# We   have  492  Legit   Transcation  and   492  Fraudlant  Transaction

# %%
new_credit_data=pd.concat([legit_sample,fraud],axis=0)
new_credit_data.head()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# 54814  46632.0 -1.018584 -0.092689  2.930103  1.332177  0.316509 -0.077635
# 90746  63150.0 -0.595084  1.214295  0.955243  0.642108 -0.133806 -0.421115
# 92865  64144.0 -1.817424  2.216421 -0.349283 -0.107746 -0.465441 -0.689390
# 14195  25229.0  1.443703 -0.377190 -0.508375 -1.042034  0.154033 -0.012187
# 27330  34505.0  1.050866 -0.169382  0.402935  0.628737  0.196794  1.307176
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 54814 -0.440264  0.182523 -0.137089  ...  0.239263  0.750589 -0.274148
# 90746  0.180797  0.440709 -0.806657  ... -0.087536 -0.367404  0.135577
# 92865 -0.304887  1.196769 -0.670991  ... -0.236691 -0.814319  0.012729
# 14195 -0.159160 -0.162228 -1.124211  ... -0.244575 -0.805131 -0.044818
# 27330 -0.409791  0.504630  0.553994  ... -0.122470 -0.045982  0.152011
#
#             V24       V25       V26       V27       V28  Amount  Class
# 54814  0.342656  0.253575 -0.105705 -0.060641 -0.126038    1.00    0.0
# 90746  0.037320 -0.749086  0.180606  0.025895  0.094750    9.99    0.0
# 92865 -0.486925  0.165586  0.134633  0.101200  0.004746    9.99    0.0
# 14195 -1.333466  0.484115 -0.418444  0.000356  0.002413   34.00    0.0
# 27330 -0.937302  0.116560  0.400046  0.045021 -0.003846    3.71    0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# Dividing The Dataset into This Independant & Dependant variable

# %%
x=new_credit_data.drop(["Class"],axis=1)
y=new_credit_data["Class"]

# %% [markdown]
# Split Data into Training and Testing Data

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (681, 30) (681,) (171, 30) (171,)

# %% [markdown]
# Applying  Logistic   Regression

# %%
model=LogisticRegression(solver='lbfgs',max_iter=1000)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred=model.predict(X_test)

# %%
model_accuracy_score=accuracy_score(y_test,y_pred)

# %% [markdown]
# Check  Accuracy  score

# %%
print(model_accuracy_score)
# Out:
# 0.9590643274853801

# %% [markdown]
# Check The Accuracy, Recall, Precision and F1-score

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97       102
#          1.0       0.97      0.93      0.95        69
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171
